# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
import seaborn as sns

# %%
df=sns.load_dataset('mpg').dropna()

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
df.head(5)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
ax=sns.histplot(x='horsepower',data=df)

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df)

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,fill=False)

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(y='horsepower',data=df,stat='count')

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,stat='probability')

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,stat='density')

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,element='step')

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,element='poly')

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,element='poly',fill=False)

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,stat='density')

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,bins=20)

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,bins=20,binrange=(70,180))

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,bins=20,kde=True)

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,bins=5,binwidth=30)

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,cumulative=True)

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,cumulative=True,element='step',fill=False)

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(y='horsepower',data=df,cumulative=True,element='step',fill=False)

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,hue='cylinders',multiple='stack',palette='summer')

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,hue='cylinders',multiple='layer',palette='summer')

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,hue='cylinders',multiple='fill',palette='summer')

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,hue='cylinders',element='poly',palette='rocket_r')

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,hue='cylinders',element='step',palette='rocket_r')

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',data=df,hue='cylinders',multiple='layer',element='step',cumulative=True,palette='rocket_r')

# %%
##BI
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',y='cylinders',data=df)

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',y='cylinders',hue='origin',data=df)

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',y='origin',data=df)

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',y='origin',data=df,cbar=True)

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
ax=sns.histplot(x='horsepower',y='cylinders',hue='origin',data=df,palette='rocket')
