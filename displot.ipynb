# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('mpg').dropna()

# %%
df['type']=['heavy' if x>2500 else 'fit' for x in df['weight'] ]
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name   type
# 0            70     usa  chevrolet chevelle malibu  heavy
# ...

# %%
fig=plt.gcf()
fig.set_size_inches(17,20)
ax=sns.displot(x='horsepower',data=df,kde=True,rug=True,lw=2,edgecolor='r')

# %%
ax=sns.displot(x='horsepower',data=df,kind='kde')

# %%
ax=sns.displot(x='horsepower',data=df,kind='kde',fill=True,lw=3)

# %%
ax=sns.displot(x='horsepower',data=df,rug=True,color='c',hatch='/')

# %%
ax=sns.displot(x='horsepower',data=df,rug=True,color='c',hatch='/',bins=10)

# %%
#BI 2
ax=sns.displot(x='horsepower',y='weight',data=df,kind='kde')

# %%
ax=sns.displot(x='horsepower',y='weight',data=df)

# %%
ax=sns.displot(x='horsepower',y='weight',data=df,rug=True,color='r')

# %%
ax=sns.displot(x='horsepower',y='weight',data=df,kind='kde',col='origin')

# %%
ax=sns.displot(x='horsepower',y='weight',data=df,kind='kde',col='origin',row='type')

# %%
ax=sns.displot(x='horsepower',y='weight',data=df,col='origin',row='type')

# %%
ax=sns.displot(x='horsepower',data=df,col='origin',row='type',color='c',hatch='*')

# %%
ax=sns.displot(x='horsepower',data=df,col='origin',row='type',color='c',facet_kws={'despine':False})
type(ax)
# Out:
# seaborn.axisgrid.FacetGrid

# %%
ax=sns.displot(kind='kde',x='horsepower',data=df,col='origin',row='type')
type(ax)
ax.set_titles(col_template='{col_name} power',row_template='{row_name} ')

# %%
ax=sns.displot(kind='kde',x='horsepower',data=df,col='origin',row='type')
ax.set_axis_labels('Horse power values')

# %%
ax=sns.displot(kind='kde',x='horsepower',data=df,col='origin',row='type',fill=True)

# %%
ax=sns.displot(kind='kde',x='horsepower',data=df,col='origin',row='type',hue='origin')

# %%
ax=sns.displot(kind='kde',x='horsepower',data=df,col='origin',row='type',hue='origin',facet_kws={'sharex': False, 'sharey': False,'despine':False})
